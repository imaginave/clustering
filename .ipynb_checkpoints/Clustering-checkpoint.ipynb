# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#import tqdm
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
from pylab import rcParams

# %%
from geopandas import GeoDataFrame
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, AffinityPropagation
from sklearn.metrics import adjusted_rand_score, silhouette_score
from shapely.geometry import Point



from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, AffinityPropagation
from sklearn.metrics import adjusted_rand_score, silhouette_score
import geopandas as gpd
# %matplotlib inline
mo_gdf = gpd.read_file('atd/mo.shp')
mo_gdf.head()
# Out:
#               NAME     OKATO     OKTMO         NAME_AO  OKATO_AO  \
# 0         Киевский  45298555  45945000        Троицкий  45298000
# 1   Филёвский Парк  45268595  45328000        Западный  45268000
# 2  Новофёдоровское  45298567  45954000        Троицкий  45298000
# 3        Роговское  45298575  45956000        Троицкий  45298000
# 4     "Мосрентген"  45297568  45953000  Новомосковский  45297000
#
#         ABBREV_AO              TYPE_MO  \
# 0        Троицкий            Поселение
# 1             ЗАО  Муниципальный округ
# 2        Троицкий            Поселение
# 3        Троицкий            Поселение
# 4  Новомосковский            Поселение
#
#                                             geometry
# 0  (POLYGON ((36.8031012 55.4408329, 36.8031903 5...
# 1  POLYGON ((37.4276499 55.7482092, 37.4284863 55...
# 2  POLYGON ((36.8035692 55.4516224, 36.8045117 55...
# 3  POLYGON ((36.9372397 55.2413907, 36.9372604 55...
# 4  POLYGON ((37.4395575 55.6273129, 37.4401803 55...

# %%
data = pd.read_excel('geo.xlsx')

# %%
data_agreed = data[data.comment_class==1].drop('comment_class', axis=1)
data_decline = data[data.comment_class==-1].drop('comment_class', axis=1)

# %%
data_coords = data[['x','y']]
data_agreed_coords = data_agreed[['x','y']]
data_decline_coords = data_decline[['x','y']]
data_coords_arr = np.array(data_coords)
data_agreed_coords_arr = np.array(data_agreed_coords)
data_decline_coords_arr = np.array(data_decline_coords)

# %%
clusters = KMeans(n_clusters=125).fit_predict(data_coords_arr)
plt.scatter(data_coords_arr[:, 0], data_coords_arr[:, 1], c=clusters, cmap='Accent', s=0.5)

# %%
clusters = KMeans(n_clusters=125).fit_predict(data_agreed_coords_arr)
plt.scatter(data_agreed_coords_arr[:, 0], data_agreed_coords_arr[:, 1], c=clusters, cmap='spring', s=0.5)

# %%
clusters = KMeans(n_clusters=125).fit_predict(data_decline_coords_arr)
plt.scatter(data_decline_coords_arr[:, 0], data_decline_coords_arr[:, 1], c=clusters, cmap='winter', s=0.5)

# %%
k_inertia = []
ks = range(10,130)

for k in ks:
    clf_kmeans = KMeans(n_clusters=k)
    clusters_kmeans = clf_kmeans.fit_predict(data_coords_arr, )
    k_inertia.append(clf_kmeans.inertia_)

# %%
plt.plot(ks, k_inertia)

# %%
crs = {'init': 'epsg:3857'}
def to_geodataframe ()
geometry = [Point(xy) for xy in zip(data.x, data.y)]
gdf = GeoDataFrame(data, crs=crs, geometry=geometry)
gdf_agreed = gdf[data.comment_class==1].drop(['x','y','comment_class'], axis=1)
gdf_decline = gdf[data.comment_class==-1].drop(['x','y','comment_class'], axis=1)

# %%
mo_gdf.head()
# Out:
#               NAME     OKATO     OKTMO         NAME_AO  OKATO_AO  \
# 0         Киевский  45298555  45945000        Троицкий  45298000
# 1   Филёвский Парк  45268595  45328000        Западный  45268000
# 2  Новофёдоровское  45298567  45954000        Троицкий  45298000
# 3        Роговское  45298575  45956000        Троицкий  45298000
# 4     "Мосрентген"  45297568  45953000  Новомосковский  45297000
#
#         ABBREV_AO              TYPE_MO  \
# 0        Троицкий            Поселение
# 1             ЗАО  Муниципальный округ
# 2        Троицкий            Поселение
# 3        Троицкий            Поселение
# 4  Новомосковский            Поселение
#
#                                             geometry
# 0  (POLYGON ((36.8031012 55.4408329, 36.8031903 5...
# 1  POLYGON ((37.4276499 55.7482092, 37.4284863 55...
# 2  POLYGON ((36.8035692 55.4516224, 36.8045117 55...
# 3  POLYGON ((36.9372397 55.2413907, 36.9372604 55...
# 4  POLYGON ((37.4395575 55.6273129, 37.4401803 55...

# %%
mo_gdf.plot()

# %%
base = mo_gdf.plot( edgecolor='black', column = 'ABBREV_AO', linewidth=0.5,legend=True,figsize=[18,18])
gdf.plot(ax=base, marker='o', color='red', markersize=0.5);

# %% [markdown]
# Кластеризация

# %%
dat

# %%
clusters = KMeans(n_clusters=125).fit_predict(data_coords)
plt.scatter(data_coords[:, 0], data_coords[:, 1], c=clusters, cmap='autumn', s=0.5)

# %%
plt.scatter(data_coords[:, 0], data_coords[:, 1], c=clusters, cmap='autumn', s=0.5)

# %%
data_coords[:, 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-5f02d0d1ff90> in <module>()
# ----> 1 data_coords[:, 0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1838         """Return the cached item, item represents a label indexer."""
#    1839         cache = self._item_cache
# -> 1840         res = cache.get(item)
#    1841         if res is None:
#    1842             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %%
plt.scatter(data_coords[:, 0], data_coords[:, 1], c=clusters, cmap='autumn', s=60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-851530870ed4> in <module>()
# ----> 1 plt.scatter(data_coords[:, 0], data_coords[:, 1], c=clusters, cmap='autumn', s=60)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1838         """Return the cached item, item represents a label indexer."""
#    1839         cache = self._item_cache
# -> 1840         res = cache.get(item)
#    1841         if res is None:
#    1842             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'
